# %%
import pandas as pd

# %%
import numpy as np

# %%
dataset = pd.read_csv("Placement.csv")

# %%
from Univariate_analysis import Univariate

# %%
Quan,Qual = Univariate.QuanQual(dataset)

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
desc = Univariate.descriptive(dataset,Quan)
# Out:
# D:\AI Course\Data Science\Frequency\Univariate_analysis.py:24: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[ColumnName]["Mean"]=dataset[ColumnName].mean()
# ...

# %%
desc
# Out:
#           sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean      108.0   NaN   NaN      NaN     NaN   NaN    NaN
# Median    108.0   NaN   NaN      NaN     NaN   NaN    NaN
# Mode          1   NaN   NaN      NaN     NaN   NaN    NaN
# Q1:25%     54.5   NaN   NaN      NaN     NaN   NaN    NaN
# Q2:50%    108.0   NaN   NaN      NaN     NaN   NaN    NaN
# Q3:75%    161.5   NaN   NaN      NaN     NaN   NaN    NaN
# 99%      212.86   NaN   NaN      NaN     NaN   NaN    NaN
# Q4:100%   215.0   NaN   NaN      NaN     NaN   NaN    NaN
# IQR       107.0   NaN   NaN      NaN     NaN   NaN    NaN
# 1.5rule   160.5   NaN   NaN      NaN     NaN   NaN    NaN
# Lesser   -106.0   NaN   NaN      NaN     NaN   NaN    NaN
# Greater   322.0   NaN   NaN      NaN     NaN   NaN    NaN
# Min           1   NaN   NaN      NaN     NaN   NaN    NaN
# Max         215   NaN   NaN      NaN     NaN   NaN    NaN

# %%
Univariate.freqTable("ssc_p", dataset)
# Out:
#      Unique_values  Frequency  Relative_Frequency  Cumulative_Frequency
# 0            62.00         11            0.106796              0.106796
# 1            63.00         10            0.097087              0.203883
# 2            67.00          9            0.087379              0.291262
# 3            52.00          9            0.087379              0.378641
# 4            73.00          9            0.087379              0.466019
# ..             ...        ...                 ...                   ...
# 98           69.70          1            0.009709              2.048544
# 99           80.92          1            0.009709              2.058252
# 100          83.00          1            0.009709              2.067961
# 101          86.50          1            0.009709              2.077670
# 102          80.60          1            0.009709              2.087379
#
# [103 rows x 4 columns]
